# %%
#hello world mlvtools
"""
:param str run: accession
:dvc-extra: run
:dvc-out: data/output/run.tsv
run = "sra:SRR1521445"
"""
# Out:
# '\n:param str run: accession\n:dvc-extra: run\n:dvc-out: data/output/run.tsv\nrun = "sra:SRR1521445"\n'

# %%
from pathlib import Path
if(Path("./data").exists):
    base_dir = Path("./")
else
    base_dir = base_dir if (base_dir / "data").exists else Path("../../")
print(base_dir.absolute())

data_dir = base_dir / "data"
input_dir = data_dir / "input"
output_dir =  data_dir / "output"
expressions_dir = input_dir / "expressions"
# Out:
# /data/sources/species/pipeline/notebooks

# %%
(Path("../../") / "data").exists()
# Out:
# True

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
m = pd.read_csv(expressions_dir / "mammals_expressions.tsv", sep = "\t")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-4453d0a28455> in <module>
# ----> 1 m = pd.read_csv(expressions_dir / "mammals_expressions.tsv", sep = "\t")
#
# /data/miniconda3/envs/species/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /data/miniconda3/envs/species/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /data/miniconda3/envs/species/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /data/miniconda3/envs/species/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /data/miniconda3/envs/species/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File data/input/expressions/mammals_expressions.tsv does not exist: 'data/input/expressions/mammals_expressions.tsv'

# %%
# No effect
m.head(10)
# Out:
#                   gene  sra:SRR1521445  sra:SRR3715877  sra:SRR5008362  \
# 0  ens:ENSG00000005187        1.074543       11.982082        4.034898
# 1  ens:ENSG00000011295       48.773984       74.765240        6.396629
# 2  ens:ENSG00000101049        1.896771        5.731442        0.058432
# 3  ens:ENSG00000013503        3.334980        5.558531        4.437732
# 4  ens:ENSG00000025796       41.400001       94.451842       18.276322
# 5  ens:ENSG00000034971        0.113781        4.795370        0.187458
# 6  ens:ENSG00000026508        3.208054      360.480248        5.497159
# 7  ens:ENSG00000117560        0.038276        2.875599        0.022460
# 8  ens:ENSG00000009954       13.130812       39.932848        3.535414
# 9  ens:ENSG00000004455       83.806333       89.585686      300.143698
#
#    sra:SRR5120939  sra:SRR5120940  sra:SRR5885325  sra:SRR5961830  \
# 0       10.242399       10.323494      121.701589        2.493206
# 1       34.726262       31.188911       25.869720      172.058677
# 2        0.396843        0.786861       40.191094        2.747328
# 3        4.065451        3.050765        2.537391       17.727609
# 4       36.607273       39.531532       19.548411      149.846511
# 5        4.013087        3.873187        0.054180        0.000000
# 6      253.990153      293.389101        6.065691        4.675374
# 7        1.490075        2.587838        0.057722        0.192682
# 8       31.832601       22.077698        6.066031       56.682982
# 9       88.511475       77.351796      188.888933       74.146858
#
#    sra:SRR5961875  sra:SRR5961972  ...  sra:ERR1331708  sra:ERR1331709  \
# 0        1.139761        3.051940  ...       87.951072       39.048030
# 1      139.699719      166.993471  ...        4.163198        5.740992
# 2        4.029975        3.682667  ...       75.934098       27.877231
# 3       22.067748       19.500810  ...       10.070366       11.620288
# 4      119.705740      167.104843  ...       69.391455       71.383856
# 5        0.000000        0.000000  ...        6.932593        2.368994
# 6        2.964542       14.816795  ...             NaN             NaN
# 7        0.093546        0.199825  ...        1.062197        0.377898
# 8       47.857375       50.099662  ...       17.816350       16.631038
# 9       42.443731       61.662265  ...      200.382569      143.757053
#
#    sra:SRR3195085  sra:SRR636887  sra:SRR636888  sra:SRR636932  sra:SRR636933  \
# 0        0.000000            NaN            NaN            NaN            NaN
# 1        0.198757       1.993971       0.421363      48.373005      39.990194
# 2        0.000000      29.329411      26.430999      97.361625      75.499285
# 3        3.631996       8.637395       5.627661      11.086683       8.277696
# 4       15.746863       7.314317       4.258517      87.297209      96.545530
# 5        0.000000            NaN            NaN            NaN            NaN
# 6       88.966004            NaN            NaN            NaN            NaN
# 7             NaN            NaN            NaN            NaN            NaN
# 8        3.344084       1.750660       1.902298      26.833412      30.542117
# 9       74.465859      66.896252      26.212440     251.986312     260.468267
#
#    sra:SRR636977  sra:SRR636978  Unnamed: 392
# 0            NaN            NaN           NaN
# 1     106.403152      60.056368           NaN
# 2       5.613916       7.543991           NaN
# 3      16.510069      11.427511           NaN
# 4      32.044565      14.498782           NaN
# 5            NaN            NaN           NaN
# 6            NaN            NaN           NaN
# 7            NaN            NaN           NaN
# 8      14.400495       9.111810           NaN
# 9      15.428476      11.238394           NaN
#
# [10 rows x 393 columns]

# %%
m.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5444aa7d268e> in <module>
# ----> 1 m.isnull()
#
# NameError: name 'm' is not defined

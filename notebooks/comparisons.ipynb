# %%
from yspecies import *
from yspecies.enums import *
from yspecies.dataset import *
from yspecies.misc import *

# %%
from typing import *
import pandas as pd
import shap
from pprint import pprint
import random
import numpy as np
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from scipy.stats import kendalltau
from sklearn.utils import resample
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, accuracy_score, recall_score, precision_score, f1_score
from pathlib import Path

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# save label encoder to global scope
le = LabelEncoder()
NUMBER_OF_BOOTSTRAPS = 5

# %% [markdown]
# ### Load pathes ###

# %%
from pathlib import Path
locations: Locations = Locations("./") if Path("./data").exists() else Locations("../")

# %%
external = shap_results = locations.output / "external" 
shap = external / "shap"
linear = external / "linear"
causality = external / "causality"

# %% [markdown]
# ### Load linear ###

# %%
def lag_linear(df: pd.DataFrame, sign: int)->pd.DataFrame:
    selected = df[df["maxlifespan_sign"]==sign][["symbol","organ","maxlifespan_adjpval","maxlifespan_r2_adj"]].sort_values(by="maxlifespan_r2_adj", ascending=False).drop_duplicates()
    return selected #.groupby("symbol","organ", as_index=False).agg({'organ': ' '.join, 'maxlifespan_r2_adj': ' '.join})


def pro_linear(df: pd.DataFrame)->pd.DataFrame:
    return lag_linear(df, 1)
   
def anti_linear(df: pd.DataFrame)->pd.DataFrame:
    return lag_linear(df, -1)

# %%
anti_linear_organ =  anti_linear(linear_organ).groupby(["reference_gene","symbol"]).agg({'organ': lambda value: value.to_list(), "maxlifespan_r2_adj": lambda value: value.to_list()})
pro_linear_organ =  pro_linear(linear_organ).groupby(["reference_gene","symbol"]).agg({'organ': lambda value: value.to_list(), "maxlifespan_r2_adj": lambda value: value.to_list()})
pro_linear_organ.head(5)
# Out:
#                            organ     maxlifespan_r2_adj
# reference_gene  symbol
# ENSG00000000003 TSPAN6   [Liver]  [0.35423811520000004]
# ENSG00000000457 SCYL3     [Lung]  [0.35033806590000005]
# ENSG00000001461 NIPAL3   [Liver]          [0.322943983]
# ENSG00000003249 DBNDD1  [Kidney]         [0.3246580106]
# ENSG00000003402 CFLAR    [Heart]         [0.3863581705]

# %%
linear_blk = load_table(linear /'Significant in B,L,K.tsv').set_index("reference_gene")
linear_organ = load_table(linear / 'with_organ_indicator_columns.tsv').set_index("reference_gene")
pro_linear(linear_organ).head(10)
# Out:
#                    symbol  organ  maxlifespan_adjpval  maxlifespan_r2_adj
# reference_gene
# ENSG00000136436  CALCOCO2  Liver                0.000               0.857
# ENSG00000136436  CALCOCO2   Lung                0.000               0.834
# ENSG00000101190     TCFL5   Lung                0.000               0.766
# ENSG00000100889      PCK2  Liver                0.000               0.760
# ENSG00000088992      TESC   Lung                0.000               0.753
# ENSG00000141736     ERBB2  Liver                0.000               0.744
# ENSG00000170190   SLC16A5   Lung                0.000               0.742
# ENSG00000164649    CDCA7L   Lung                0.000               0.740
# ENSG00000177000     MTHFR   Lung                0.000               0.711
# ENSG00000112699      GMDS  Liver                0.000               0.704

# %%
linear_models = load_table(linear / 'linear_models_on_species_vars.tsv').set_index("reference_gene")
linear_all = load_table(linear / 'Significant in all organs.tsv').set_index("reference_gene")
linear_pro = linear_all[linear_all["maxlifespan_sign"]==1].sort_values(by="maxlifespan_r2_adj", ascending = False)
linear_anti = linear_all[linear_all["maxlifespan_sign"]==-1].sort_values(by="maxlifespan_r2_adj", ascending = True)
linear_pro
# Out:
#                    symbol   organ  human_samples  maxlifespan_adjpval  \
# reference_gene
# ENSG00000136436  CALCOCO2   Liver  withoutHumans                0.000
# ENSG00000136436  CALCOCO2    Lung  withoutHumans                0.000
# ENSG00000269190    FBXO17   Liver  withoutHumans                0.000
# ENSG00000136436  CALCOCO2   Heart  withoutHumans                0.000
# ENSG00000136436  CALCOCO2   Brain  withoutHumans                0.000
# ENSG00000006282   SPATA20   Heart  withoutHumans                0.000
# ENSG00000006282   SPATA20    Lung  withoutHumans                0.000
# ENSG00000269190    FBXO17  Kidney  withoutHumans                0.000
# ENSG00000006282   SPATA20   Brain  withoutHumans                0.000
# ENSG00000165501      LRR1    Lung  withoutHumans                0.001
# ENSG00000165501      LRR1   Liver  withoutHumans                0.000
# ENSG00000136436  CALCOCO2  Kidney  withoutHumans                0.000
# ENSG00000165501      LRR1   Brain  withoutHumans                0.000
# ENSG00000165501      LRR1   Heart  withoutHumans                0.002
# ENSG00000006282   SPATA20  Kidney  withoutHumans                0.000
# ENSG00000269190    FBXO17    Lung  withoutHumans                0.015
# ENSG00000269190    FBXO17   Brain  withoutHumans                0.000
# ENSG00000006282   SPATA20   Liver  withoutHumans                0.000
# ENSG00000269190    FBXO17   Heart  withoutHumans                0.009
# ENSG00000165501      LRR1  Kidney  withoutHumans                0.000
#
#                  maxlifespan_r2_adj  maxlifespan_n_obs  maxlifespan_sign  \
# reference_gene
# ENSG00000136436               0.857                 83                 1
# ENSG00000136436               0.834                 22                 1
# ENSG00000269190               0.693                 97                 1
# ENSG00000136436               0.693                 29                 1
# ENSG00000136436               0.691                 89                 1
# ENSG00000006282               0.611                 29                 1
# ENSG00000006282               0.576                 23                 1
# ENSG00000269190               0.562                 53                 1
# ENSG00000006282               0.531                100                 1
# ENSG00000165501               0.519                 23                 1
# ENSG00000165501               0.477                 96                 1
# ENSG00000136436               0.470                 52                 1
# ENSG00000165501               0.440                 94                 1
# ENSG00000165501               0.395                 29                 1
# ENSG00000006282               0.374                 60                 1
# ENSG00000269190               0.372                 20                 1
# ENSG00000269190               0.370                 91                 1
# ENSG00000006282               0.368                103                 1
# ENSG00000269190               0.315                 27                 1
# ENSG00000165501               0.308                 54                 1
#
#                  mass_adjpval  mass_r2_adj  mass_n_obs  mass_sign  \
# reference_gene
# ENSG00000136436         0.116        0.068          83          1
# ENSG00000136436         0.342        0.116          22          1
# ENSG00000269190         0.003        0.153          97          1
# ENSG00000136436         0.280        0.108          29          1
# ENSG00000136436         0.052        0.088          89          1
# ENSG00000006282         0.360        0.080          29          1
# ENSG00000006282         0.477        0.060          23          1
# ENSG00000269190         0.937       -0.018          53          1
# ENSG00000006282         0.777       -0.005         100          1
# ENSG00000165501         0.427        0.078          23          1
# ENSG00000165501         0.644        0.002          96          1
# ENSG00000136436         0.178        0.086          52          1
# ENSG00000165501         0.205        0.043          94          1
# ENSG00000165501         0.263        0.115          29          1
# ENSG00000006282         0.246        0.058          60          1
# ENSG00000269190         0.880       -0.044          20          1
# ENSG00000269190         0.919       -0.010          91         -1
# ENSG00000006282         0.001        0.173         103          1
# ENSG00000006282                              False
# ENSG00000165501                              False
# ENSG00000165501                              False
# ENSG00000136436                              False
# ENSG00000165501                              False
# ENSG00000165501                              False
# ENSG00000006282                              False
# ENSG00000269190                              False
# ENSG00000269190                              False
# ENSG00000006282                              False
# ENSG00000269190                              False
# ENSG00000165501                              False
#
#                  gestation_uniquely_associated  mtGC_uniquely_associated  \
# reference_gene
# ENSG00000136436                          False                     False
# ENSG00000136436                          False                     False
# ENSG00000269190                          False                     False
# ENSG00000136436                          False                     False
# ENSG00000136436                          False                     False
# ENSG00000006282                          False                     False
# ENSG00000006282                          False                     False
# ENSG00000269190                          False                     False
# ENSG00000006282                          False                     False
# ENSG00000165501                          False                     False
# ENSG00000165501                          False                     False
# ENSG00000136436                          False                     False
# ENSG00000165501                          False                     False
# ENSG00000165501                          False                     False
# ENSG00000006282                          False                     False
# ENSG00000269190                          False                     False
# ENSG00000269190                          False                     False
# ENSG00000006282                          False                     False
# ENSG00000269190                          False                     False
# ENSG00000165501                          False                     False
#
#                  is_maxls_associated_in_Brain  is_maxls_associated_in_Heart  \
# reference_gene
# ENSG00000136436                          True                          True
# ENSG00000136436                          True                          True
# ENSG00000269190                          True                          True
# ENSG00000136436                          True                          True
# ENSG00000136436                          True                          True
# ENSG00000006282                          True                          True
# ENSG00000006282                          True                          True
# ENSG00000269190                          True                          True
# ENSG00000006282                          True                          True
# ENSG00000165501                          True                          True
# ENSG00000165501                          True                          True
# ENSG00000136436                          True                          True
# ENSG00000165501                          True                          True
# ENSG00000165501                          True                          True
# ENSG00000006282                          True                          True
# ENSG00000269190                          True                          True
# ENSG00000269190                          True                          True
# ENSG00000006282                          True                          True
# ENSG00000269190                          True                          True
# ENSG00000165501                          True                          True
#
#                  is_maxls_associated_in_Lung  is_maxls_associated_in_Liver  \
# reference_gene
# ENSG00000136436                         True                          True
# ENSG00000136436                         True                          True
# ENSG00000269190                         True                          True
# ENSG00000136436                         True                          True
# ENSG00000136436                         True                          True
# ENSG00000006282                         True                          True
# ENSG00000006282                         True                          True
# ENSG00000269190                         True                          True
# ENSG00000006282                         True                          True
# ENSG00000165501                         True                          True
# ENSG00000165501                         True                          True
# ENSG00000136436                         True                          True
# ENSG00000165501                         True                          True
# ENSG00000165501                         True                          True
# ENSG00000006282                         True                          True
# ENSG00000269190                         True                          True
# ENSG00000269190                         True                          True
# ENSG00000006282                         True                          True
# ENSG00000269190                         True                          True
# ENSG00000165501                         True                          True
#
#                  is_maxls_associated_in_Kidney
# reference_gene
# ENSG00000136436                           True
# ENSG00000136436                           True
# ENSG00000269190                           True
# ENSG00000136436                           True
# ENSG00000136436                           True
# ENSG00000006282                           True
# ENSG00000006282                           True
# ENSG00000269190                           True
# ENSG00000006282                           True
# ENSG00000165501                           True
# ENSG00000165501                           True
# ENSG00000136436                           True
# ENSG00000165501                           True
# ENSG00000165501                           True
# ENSG00000006282                           True
# ENSG00000269190                           True
# ENSG00000269190                           True
# ENSG00000006282                           True
# ENSG00000269190                           True
# ENSG00000165501                           True

# %%
linear_all.shape
# Out:
# (20, 38)

# %% [markdown]
# ### Load shap ###

# %%
def pro_genes(df: pd.DataFrame, threshold:float = 0.3) -> pd.DataFrame:
    return df[df["kendall_tau_to_max_lifespan"]>threshold].sort_values(by="kendall_tau_to_max_lifespan", ascending=False)

def pro(df: pd.DataFrame, threshold:float = 0.3) -> pd.DataFrame:
    return pro_genes(df, threshold)[['ids','name', 'gain_score_to_max_lifespan', 'kendall_tau_to_max_lifespan']]

def anti_genes(df: pd.DataFrame, threshold:float = -0.3) -> pd.DataFrame:
    return df[df["kendall_tau_to_max_lifespan"]<threshold].sort_values(by="kendall_tau_to_max_lifespan", ascending=True)

def anti(df: pd.DataFrame, threshold:float = -0.3) -> pd.DataFrame:
    return anti_genes(df, threshold)[['ids','name', 'gain_score_to_max_lifespan', 'kendall_tau_to_max_lifespan']]

# %%
anton_5_5 = pd.read_csv(shap / "5_tissues_anton_species_5_bootstraps.csv", index_col=0)
eugen_5_5 = pd.read_csv(shap / "5_tissues_data_11_06_eugene_species.csv", index_col=0)
anton_7_4 = pd.read_csv(shap / "7_tissues_anton_species_4_bootstraps.csv", index_col=0)
current = anton_5_5
pro_short(current)
# Out:
#                 ids      name  gain_score_to_max_lifespan  \
# 89  ENSG00000069275    NUCKS1                    2750.898
# 14  ENSG00000160323  ADAMTS13                    4504.608
# 39  ENSG00000129187      DCTD                   83059.823
# 53  ENSG00000146215     CRIP3                    1580.386
# 6   ENSG00000157343    ARMC12                   14611.846
# 75  ENSG00000116030     SUMO1                    1250.186
# 65  ENSG00000148175      STOM                    1011.608
# 43  ENSG00000006282   SPATA20                   67496.807
# 45  ENSG00000073146   MOV10L1                    4217.064
# 25  ENSG00000168060  NAALADL1                    4438.045
# 84  ENSG00000170417   TMEM182                     623.907
# 54  ENSG00000088992      TESC                    8600.729
# 62  ENSG00000107551    RASSF4                   39677.401
# 35  ENSG00000166436    TRIM66                     398.831
# 13  ENSG00000133256     PDE6B                   25037.261
# 52  ENSG00000099783    HNRNPM                     477.721
# 82  ENSG00000134308     YWHAQ                    1079.746
# 28  ENSG00000198746   GPATCH3                     632.153
# 76  ENSG00000106066      CPVL                     894.426
# 7   ENSG00000104763     ASAH1                    1313.825
# 32  ENSG00000083896    YTHDC1                  190349.720
#
#     kendall_tau_to_max_lifespan
# 89                        0.715
# 14                        0.693
# 39                        0.640
# 53                        0.639
# 6                         0.637
# 75                        0.620
# 65                        0.607
# 43                        0.593
# 45                        0.584
# 25                        0.580
# 84                        0.573
# 54                        0.545
# 62                        0.542
# 35                        0.533
# 13                        0.515
# 52                        0.458
# 82                        0.438
# 28                        0.431
# 76                        0.391
# 7                         0.321
# 32                        0.316

# %%
pro_short(anton_5_5)[["ids" ,"name"]].merge(pro_short(anton_7_4)[["ids" ,"name"]], on=["ids" ,"name"], how="outer", indicator=True).sort_values("_merge", ascending=False)
# Out:
#                 ids      name      _merge
# 0   ENSG00000069275    NUCKS1        both
# 12  ENSG00000107551    RASSF4        both
# 20  ENSG00000083896    YTHDC1        both
# 18  ENSG00000106066      CPVL        both
# 16  ENSG00000134308     YWHAQ        both
# 1   ENSG00000160323  ADAMTS13        both
# 14  ENSG00000133256     PDE6B        both
# 13  ENSG00000166436    TRIM66        both
# 15  ENSG00000099783    HNRNPM        both
# 7   ENSG00000006282   SPATA20        both
# 5   ENSG00000116030     SUMO1        both
# 4   ENSG00000157343    ARMC12        both
# 3   ENSG00000146215     CRIP3        both
# 2   ENSG00000129187      DCTD        both
# 29  ENSG00000129071      MBD4  right_only
# 23  ENSG00000139344    AMDHD1  right_only
# 28  ENSG00000096060     FKBP5  right_only
# 27  ENSG00000162994     CLHC1  right_only
# 26  ENSG00000138382    METTL5  right_only
# 25  ENSG00000120129     DUSP1  right_only
# 24  ENSG00000117697      NSL1  right_only
# 21  ENSG00000051620     HEBP2  right_only
# 22  ENSG00000135617    PRADC1  right_only
# 9   ENSG00000168060  NAALADL1   left_only
# 10  ENSG00000170417   TMEM182   left_only
# 17  ENSG00000198746   GPATCH3   left_only
# 6   ENSG00000148175      STOM   left_only
# 8   ENSG00000073146   MOV10L1   left_only
# 11  ENSG00000088992      TESC   left_only
# 19  ENSG00000104763     ASAH1   left_only

# %%
anti_short(current)
# Out:
#                  ids     name  gain_score_to_max_lifespan  \
# 45   ENSG00000170222    ADPRM                   17010.513
# 32   ENSG00000047230    CTPS2                   11354.686
# 8    ENSG00000198663  C6orf89                   18147.176
# 64   ENSG00000135940    COX5B                     909.851
# 1    ENSG00000214827    MTCP1                    6574.880
# 125  ENSG00000147123  NDUFB11                   32642.913
# 53   ENSG00000107815     TWNK                   16575.278
# 103  ENSG00000143771    CNIH4                      94.746
# 38   ENSG00000069869    NEDD4                   22288.713
# 62   ENSG00000163584  RPL22L1                     376.824
# 61   ENSG00000107949    BCCIP                    3462.926
# 3    ENSG00000149577    SIDT2                   19820.197
# 46   ENSG00000172594  SMPDL3A                    9518.289
# 76   ENSG00000164879      CA3                   37958.539
#
#      kendall_tau_to_max_lifespan
# 45                        -0.765
# 32                        -0.717
# 8                         -0.716
# 64                        -0.687
# 1                         -0.656
# 125                       -0.641
# 53                        -0.602
# 103                       -0.545
# 38                        -0.542
# 62                        -0.522
# 61                        -0.519
# 3                         -0.511
# 46                        -0.439
# 76                        -0.310

# %% [markdown]
# ### Causality ###

# %% [markdown]
# ### Intesection ###

# %%
causal_anton_5_5 = pd.read_csv(causality / "causal_relations_5_tissues_species_5.csv")
fathers = (causal_anton_5_5[causal_anton_5_5["predicate"] == "is father of"])[["node1"]].drop_duplicates().rename(columns={"node1": "name"})
fathers
# Out:
#         name
# 0     PICALM
# 8    SPATA20
# 14    NUCKS1
# 18    HNRNPM
# 28      DCTD
# 34     LIMD2
# 36   NDUFB11
# 37      STOM
# 39     SIDT2
# 41  ADAMTS13
# 45    TRIM66
# 46   TMEM182
# 47    KLHL33
# 48   C6orf89
# 49   GPATCH3
# 50     MTCP1
# 51     STPG4
# 54      GNL1

# %% [markdown]
# ### pro-longevity ###

# %%
pro_cur_merge = pro(current).merge(fathers, on="name", how="left", indicator = True).sort_values(by="_merge", ascending=False)
pro_cur_merge["_merge"] = pro_cur_merge["_merge"]=="both"
pro_cur = pro_cur_merge.rename(columns={"_merge": "causal", "ids": "reference_gene", "name": "symbol"}).set_index("reference_gene")
pro_cur
# Out:
#                    symbol  gain_score_to_max_lifespan  \
# reference_gene
# ENSG00000069275    NUCKS1                    2750.898
# ENSG00000006282   SPATA20                   67496.807
# ENSG00000198746   GPATCH3                     632.153
# ENSG00000099783    HNRNPM                     477.721
# ENSG00000166436    TRIM66                     398.831
# ENSG00000160323  ADAMTS13                    4504.608
# ENSG00000170417   TMEM182                     623.907
# ENSG00000148175      STOM                    1011.608
# ENSG00000129187      DCTD                   83059.823
# ENSG00000073146   MOV10L1                    4217.064
# ENSG00000168060  NAALADL1                    4438.045
# ENSG00000116030     SUMO1                    1250.186
# ENSG00000088992      TESC                    8600.729
# ENSG00000107551    RASSF4                   39677.401
# ENSG00000157343    ARMC12                   14611.846
# ENSG00000133256     PDE6B                   25037.261
# ENSG00000146215     CRIP3                    1580.386
# ENSG00000134308     YWHAQ                    1079.746
# ENSG00000106066      CPVL                     894.426
# ENSG00000104763     ASAH1                    1313.825
# ENSG00000083896    YTHDC1                  190349.720
#
#                  kendall_tau_to_max_lifespan  causal
# reference_gene
# ENSG00000069275                        0.715    True
# ENSG00000006282                        0.593    True
# ENSG00000198746                        0.431    True
# ENSG00000099783                        0.458    True
# ENSG00000166436                        0.533    True
# ENSG00000160323                        0.693    True
# ENSG00000170417                        0.573    True
# ENSG00000148175                        0.607    True
# ENSG00000129187                        0.640    True
# ENSG00000073146                        0.584   False
# ENSG00000168060                        0.580   False
# ENSG00000116030                        0.620   False
# ENSG00000088992                        0.545   False
# ENSG00000107551                        0.542   False
# ENSG00000157343                        0.637   False
# ENSG00000133256                        0.515   False
# ENSG00000146215                        0.639   False
# ENSG00000134308                        0.438   False
# ENSG00000106066                        0.391   False
# ENSG00000104763                        0.321   False
# ENSG00000083896                        0.316   False

# %%
pro_all = pro_cur.merge(pro_linear_organ,on="reference_gene").rename({"organ": "organs_in_linear_models", "maxlifespan_r2_adj": "r2_adjusted_in_linear_models"})
pro_all
# Out:
#                    symbol  gain_score_to_max_lifespan  \
# reference_gene
# ENSG00000069275    NUCKS1                    2750.898
# ENSG00000006282   SPATA20                   67496.807
# ENSG00000166436    TRIM66                     398.831
# ENSG00000160323  ADAMTS13                    4504.608
# ENSG00000148175      STOM                    1011.608
# ENSG00000129187      DCTD                   83059.823
# ENSG00000073146   MOV10L1                    4217.064
# ENSG00000168060  NAALADL1                    4438.045
# ENSG00000088992      TESC                    8600.729
# ENSG00000107551    RASSF4                   39677.401
# ENSG00000106066      CPVL                     894.426
#
#                  kendall_tau_to_max_lifespan  causal  \
# reference_gene
# ENSG00000069275                        0.715    True
# ENSG00000006282                        0.593    True
# ENSG00000166436                        0.533    True
# ENSG00000160323                        0.693    True
# ENSG00000148175                        0.607    True
# ENSG00000129187                        0.640    True
# ENSG00000073146                        0.584   False
# ENSG00000168060                        0.580   False
# ENSG00000088992                        0.545   False
# ENSG00000107551                        0.542   False
# ENSG00000106066                        0.391   False
#
#                                                organ  \
# reference_gene
# ENSG00000069275                              [Liver]
# ENSG00000006282  [Heart, Lung, Brain, Kidney, Liver]
# ENSG00000166436                              [Liver]
# ENSG00000160323                             [Kidney]
# ENSG00000148175                [Liver, Brain, Heart]
# ENSG00000129187          [Liver, Brain, Heart, Lung]
# ENSG00000073146                              [Brain]
# ENSG00000168060                               [Lung]
# ENSG00000088992          [Lung, Heart, Liver, Brain]
# ENSG00000107551        [Brain, Kidney, Heart, Liver]
# ENSG00000106066                              [Liver]
#
#                                                 maxlifespan_r2_adj
# reference_gene
# ENSG00000069275                                     [0.4726572737]
# ENSG00000006282  [0.6113832167000001, 0.5762836314, 0.531100971...
# ENSG00000166436                                     [0.4858931016]
# ENSG00000160323                                     [0.3313540606]
# ENSG00000148175         [0.5172275418, 0.4163506322, 0.3428729781]
# ENSG00000129187  [0.6643585026, 0.3519032766, 0.3409784978, 0.3...
# ENSG00000073146                              [0.35540965729999996]
# ENSG00000168060                              [0.37849600710000003]
# ENSG00000088992  [0.7526756858, 0.5605093436, 0.410325594099999...
# ENSG00000107551  [0.5111682018, 0.3925895854, 0.367612583500000...
# ENSG00000106066                                     [0.3137670346]

# %%
intersections = locations.output / "intersections"
pro_all.to_csv(intersections / "pro_intersections.tsv", sep = "\t", index = True)

# %% [markdown]
# ### anti-longevity ###

# %%
anti_cur_merge = anti(current).merge(fathers, on="name", how="left", indicator = True).sort_values(by="_merge", ascending=False)
anti_cur_merge["_merge"] = anti_cur_merge["_merge"]=="both"
anti_cur = anti_cur_merge.rename(columns={"_merge": "causal", "ids": "reference_gene", "name": "symbol"}).set_index("reference_gene")
anti_cur
# Out:
#                   symbol  gain_score_to_max_lifespan  \
# reference_gene
# ENSG00000198663  C6orf89                    7371.253
# ENSG00000147123  NDUFB11                    7288.644
# ENSG00000149577    SIDT2                   17588.014
# ENSG00000185271   KLHL33                    5888.169
# ENSG00000214827    MTCP1                   36295.636
# ENSG00000107815     TWNK                   29538.657
# ENSG00000085840     ORC1                   17409.994
# ENSG00000132646     PCNA                     319.946
# ENSG00000152580   IGSF10                    5499.678
#
#                  kendall_tau_to_max_lifespan  causal
# reference_gene
# ENSG00000198663                       -0.746    True
# ENSG00000147123                       -0.703    True
# ENSG00000149577                       -0.540    True
# ENSG00000185271                       -0.525    True
# ENSG00000214827                       -0.484    True
# ENSG00000107815                       -0.717   False
# ENSG00000085840                       -0.589   False
# ENSG00000132646                       -0.439   False
# ENSG00000152580                       -0.397   False

# %%
anti_all = anti_cur.merge(anti_linear_organ,on="reference_gene").rename({"organ": "organs_in_linear_models", "maxlifespan_r2_adj": "r2_adjusted_in_linear_models"})
anti_all
# Out:
#                   symbol  gain_score_to_max_lifespan  \
# reference_gene
# ENSG00000198663  C6orf89                    7371.253
# ENSG00000149577    SIDT2                   17588.014
# ENSG00000214827    MTCP1                   36295.636
# ENSG00000132646     PCNA                     319.946
#
#                  kendall_tau_to_max_lifespan  causal            organ  \
# reference_gene
# ENSG00000198663                       -0.746    True  [Liver, Kidney]
# ENSG00000149577                       -0.540    True          [Liver]
# ENSG00000214827                       -0.484    True  [Brain, Kidney]
# ENSG00000132646                       -0.439   False          [Brain]
#
#                                   maxlifespan_r2_adj
# reference_gene
# ENSG00000198663  [0.39511734670000004, 0.3338116818]
# ENSG00000149577                [0.45368042049999996]
# ENSG00000214827  [0.40521433409999996, 0.3005427027]
# ENSG00000132646                       [0.3307226882]

# %%
anti_all.to_csv(intersections / "anti_intersections.tsv", sep = "\t", index = True)
